# %%
import difflib

def check_noisy_sentence(noisy_input):
    # 1. Load your dataset
    try:
        with open(r"D:\SLT\Test 4\my dataset.txt", 'r', encoding='utf-8') as f:
            dataset = [line.strip().replace(',', '') for line in f if line.strip()]
    except FileNotFoundError:
        print("Error: Dataset file not found. Please check your path.")
        return

    noisy_words = noisy_input.split()
    
    recovered_paragraph_words = []
    not_caught_list = []

    # Process each word for fuzzy matching (Cutoff 0.5 to catch high noise)
    for word in noisy_words:
        # We use a broad threshold to recover noisy words 
        match = difflib.get_close_matches(word, dataset, n=1, cutoff=0.5)
        
        if match:
            recovered_paragraph_words.append(match[0])
        else:
            # If no match is found even at 50%, we keep the original in brackets
            recovered_paragraph_words.append(f"[{word}]")
            not_caught_list.append(word)

    # --- OUTPUT SECTION ---

    print("### ORIGINAL NOISY TEXT")
    print("-" * 50)
    print(noisy_input.strip())
    
    print("\n" + "="*60 + "\n")

    print("### RECOVERED CLEAN PARAGRAPH (2ND OUTPUT)")
    print("-" * 50)
    print(" ".join(recovered_paragraph_words))
    
    print("\n" + "="*60 + "\n")
    
    print("### THESE ARE NOT CAUGHT AND NOT IN YOUR DATASET:")
    print("-" * 50)
    if not_caught_list:
        # Using set to show unique failures only
        for item in sorted(set(not_caught_list)):
            print(f"- {item}")
    else:
        print("None")

# Your input text
noisy_test = """රනගසරට සෞදින් හඩ දැනට කනෙක්ෂණ එක බෙල්පත නිසා දිස්කනක්වලාතිනනේ
දැනටව නොවෙඹ කාල සනොවෙබ තිහොදක්වා රුපියල් දහ තුන්දා සාරසිය හැටට දකකෂතැහැට දෙක 
කොමතල ියෙනවා බිල්පපඊමිලසරහා සෙන්කරන්නේ ිසම්බ විසිදෙක තමයි ඩූඩේටෙක තිබිලා තියෙන නොවෙම්බ
බිහටත් පේමට් ික කරත් කනෙක්ෂන් ටික ඔටෝමටික ටික වෙලාවකින් ඇත්ූවෙනවාේන් එකක් රලතියමැඩම් 
පේමන්ට් ිකක් කරලා තියෙන්නේ දිේබ විසිහට අට දාක්ිට පස්සේ ේමනට් එකක් කරතාමණං අභිටතුලා නෑ පේ 
කරපු මවන් එක කියද කයල දැනගන්න පුළුවන්ද මැඩ ්මට ඩීටෙල්ස් ටික දෙන්න පොළොන් අනුලින්ද කොොම්ද 
පේම්ික කරේබැංක කමුට් එකෙන් මැඩම්ගේ මවුන් එක දිඩක් තනාද නකන්ටාන්සික්ෂණත න්සික්ෂණ රිෆරන්ටස් නම් 
එකත් මැඩම් ලබා ගත්අදඔහුවෝ බෑන්ක් එක් අවුන්ට කේන එක අරිමං එමුනත් කමතෙන එකත් දානමට පේකරපු වෙලාව කියන්නනම්පොඩකින්
"""

check_noisy_sentence(noisy_test)
# Out:
# ### ORIGINAL NOISY TEXT
# --------------------------------------------------
# රනගසරට සෞදින් හඩ දැනට කනෙක්ෂණ එක බෙල්පත නිසා දිස්කනක්වලාතිනනේ
# දැනටව නොවෙඹ කාල සනොවෙබ තිහොදක්වා රුපියල් දහ තුන්දා සාරසිය හැටට දකකෂතැහැට දෙක
# කොමතල ියෙනවා බිල්පපඊමිලසරහා සෙන්කරන්නේ ිසම්බ විසිදෙක තමයි ඩූඩේටෙක තිබිලා තියෙන නොවෙම්බ
# බිහටත් පේමට් ික කරත් කනෙක්ෂන් ටික ඔටෝමටික ටික වෙලාවකින් ඇත්ූවෙනවාේන් එකක් රලතියමැඩම්
# පේමන්ට් ිකක් කරලා තියෙන්නේ දිේබ විසිහට අට දාක්ිට පස්සේ ේමනට් එකක් කරතාමණං අභිටතුලා නෑ පේ
# කරපු මවන් එක කියද කයල දැනගන්න පුළුවන්ද මැඩ ්මට ඩීටෙල්ස් ටික දෙන්න පොළොන් අනුලින්ද කොොම්ද
# පේම්ික කරේබැංක කමුට් එකෙන් මැඩම්ගේ මවුන් එක දිඩක් තනාද නකන්ටාන්සික්ෂණත න්සික්ෂණ රිෆරන්ටස් නම්
# එකත් මැඩම් ලබා ගත්අදඔහුවෝ බෑන්ක් එක් අවුන්ට කේන එක අරිමං එමුනත් කමතෙන එකත් දානමට පේකරපු වෙලාව කියන්නනම්පොඩකින්
#
# ...
#
# ### RECOVERED CLEAN PARAGRAPH (2ND OUTPUT)
# --------------------------------------------------
# ...

# %%
##corrected one using gemini

# %% [markdown]
# රීකනෙක්ට් කරන්න සර්විස් එක දැනට කනෙක්ෂන් එක බිල්පත නිසා ඩිස්කනෙක්ට් වෙලා තියෙන්නේ. දැනට නොවැම්බර් 30 දක්වා රුපියල් දහතුන්දා හාරසිය හැට දෙකක් පෙන්නුම් කරනවා. බිල්පත ඊමේල් හරහා සෙන්ඩ් කරලා තියෙන්නේ දෙසැම්බර් විසි දෙක. තමයි ඩියු ඩේට් එක තිබිලා තියෙන්නේ. නොවැම්බර් පේමන්ට් එක කරපු ගමන් කනෙක්ෂන් එක ඔටෝමැටිකලි ටික වෙලාවකින් ඇක්ටිව් වෙනවා. මැඩම් පේමන්ට් එකක් කරලා තියෙන්නේ දෙසැම්බර් විසි අට දායින් පස්සේ නම්, ඒ පේමන්ට් එක තවම අපිට ලැබිලා නෑ. පේ කරපු අමුන්ට් එක කීයද කියලා දැනගන්න පුළුවන්ද මැඩම්? මට ඩීටේල්ස් ටික දෙන්න පුළුවන්ද, කොහොමද පේමන්ට් එක කරේ? ඔන්ලයින්ද? බැංකු එකවුන්ට් එකෙන් මැඩම්ගේ අමුන්ට් එක අඩු වුණා නම් ට්‍රාන්සැක්ෂන් රිෆරන්ස් නම්බර් එකත් ලබා දෙන්න. බැංකු එකවුන්ට් එක අප්ඩේට් වෙන්න වෙලාවක් යනවා නම්, පේ කරපු වෙලාව කියන්න.

# %%
## Expanded version code

# %%
import difflib

def check_noisy_sentence(noisy_input):
    # 1. Load your dataset
    try:
        with open(r"D:\SLT\Test 3\my_dataset.txt", 'r', encoding='utf-8') as f:
            dataset = [line.strip().replace(',', '') for line in f if line.strip()]
    except FileNotFoundError:
        print("Error: Dataset file not found.")
        return

    noisy_words = noisy_input.split()
    
    # Lists to store the final words for paragraph reconstruction
    pass1_paragraph_words = []
    pass2_paragraph_words = []
    not_caught_list = []

    for word in noisy_words:
        # Pass 1: High Accuracy (90% match)
        match1 = difflib.get_close_matches(word, dataset, n=1, cutoff=0.9)
        
        if match1:
            pass1_paragraph_words.append(match1[0])
            pass2_paragraph_words.append(match1[0]) # If it's perfect, it goes in both
        else:
            # Word failed Pass 1, let's try Pass 2: Fuzzy Recovery (50% match)
            match2 = difflib.get_close_matches(word, dataset, n=1, cutoff=0.5)
            
            # For the first paragraph, we put a placeholder or skip if not 90%
            pass1_paragraph_words.append("_____") 
            
            if match2:
                pass2_paragraph_words.append(match2[0])
            else:
                pass2_paragraph_words.append(f"[{word}]") # Mark words totally missing
                not_caught_list.append(word)

    # --- OUTPUT ---
    
    print("### 1ST OUTPUT: HIGH ACCURACY PARAGRAPH (90% Match Only)")
    print("-" * 50)
    print(" ".join(pass1_paragraph_words))
    print("\n" + "="*60 + "\n")

    print("### 2ND OUTPUT: RECOVERED PARAGRAPH (Including 80%/Fuzzy Matches)")
    print("-" * 50)
    print(" ".join(pass2_paragraph_words))
    
    print("\n" + "="*60 + "\n")
    print("THESE ARE NOT CAUGHT AND NOT IN YOUR DATASET:")
    if not_caught_list:
        print(set(not_caught_list)) # Use set to remove duplicate failures
    else:
        print("None")

# Your Input Data
noisy_test = """රනගසරට සෞදින් හඩ දැනට කනෙක්ෂණ එක බෙල්පත නිසා දිස්කනක්වලාතිනනේ
දැනටව නොවෙඹ කාල සනොවෙබ තිහොදක්වා රුපියල් දහ තුන්දා සාරසිය හැටට දකකෂතැහැට දෙක 
කොමතල ියෙනවා බිල්පපඊමිලසරහා සෙන්කරන්නේ ිසම්බ විසිදෙක තමයි ඩූඩේටෙක තිබිලා තියෙන නොවෙම්බ
බිහටත් පේමට් ික කරත් කනෙක්ෂන් ටික ඔටෝමටික ටික වෙලාවකින් ඇත්ූවෙනවාේන් එකක් රලතියමැඩම් 
පේමන්ට් ිකක් කරලා තියෙන්නේ දිේබ විසිහට අට දාක්ිට පස්සේ ේමනට් එකක් කරතාමණං අභිටතුලා නෑ පේ 
කරපු මවන් එක කියද කයල දැනගන්න පුළුවන්ද මැඩ ්මට ඩීටෙල්ස් ටික දෙන්න පොළොන් අනුලින්ද කොොම්ද 
පේම්ික කරේබැංක කමුට් එකෙන් මැඩම්ගේ මවුන් එක දිඩක් තනාද නකන්ටාන්සික්ෂණත න්සික්ෂණ රිෆරන්ටස් නම් 
එකත් මැඩම් ලබා ගත්අදඔහුවෝ බෑන්ක් එක් අවුන්ට කේන එක අරිමං එමුනත් කමතෙන එකත් දානමට පේකරපු වෙලාව කියන්නනම්පොඩකින්
"""

check_noisy_sentence(noisy_test)
# Out:
# ### 1ST OUTPUT: HIGH ACCURACY PARAGRAPH (90% Match Only)
# --------------------------------------------------
# _____ _____ _____ දැනට _____ එක _____ නිසා _____ _____ _____ කාල _____ _____ රුපියල් _____ _____ _____ _____ _____ දෙක _____ තියෙනවා _____ _____ _____ _____ තමයි _____ තිබිලා _____ _____ _____ _____ _____ _____ කනෙක්ෂන් ටික _____ ටික වෙලාවකින් _____ එකක් _____ පේමන්ට් _____ කරලා තියෙන්නේ _____ _____ අට _____ පස්සේ _____ එකක් _____ _____ නෑ පේ කරපු _____ එක _____ _____ දැනගන්න පුළුවන්ද _____ _____ _____ ටික දෙන්න _____ _____ _____ _____ _____ _____ එකෙන් මැඩම්ගේ _____ එක _____ _____ _____ _____ _____ නම් _____ මැඩම් ලබා _____ _____ _____ _____ _____ එක _____ _____ _____ _____ _____ _____ වෙලාව _____
#
# ...
#
# ### 2ND OUTPUT: RECOVERED PARAGRAPH (Including 80%/Fuzzy Matches)
# --------------------------------------------------
# ...

# %%
## another voice input

# %%
import difflib

def check_noisy_sentence(noisy_input):
    # 1. Load your dataset
    try:
        with open(r"D:\SLT\Test 3\my_dataset.txt", 'r', encoding='utf-8') as f:
            dataset = [line.strip().replace(',', '') for line in f if line.strip()]
    except FileNotFoundError:
        print("Error: Dataset file not found.")
        return

    noisy_words = noisy_input.split()
    
    # Lists to store the final words for paragraph reconstruction
    pass1_paragraph_words = []
    pass2_paragraph_words = []
    not_caught_list = []

    for word in noisy_words:
        # Pass 1: High Accuracy (90% match)
        match1 = difflib.get_close_matches(word, dataset, n=1, cutoff=0.9)
        
        if match1:
            pass1_paragraph_words.append(match1[0])
            pass2_paragraph_words.append(match1[0]) # If it's perfect, it goes in both
        else:
            # Word failed Pass 1, let's try Pass 2: Fuzzy Recovery (50% match)
            match2 = difflib.get_close_matches(word, dataset, n=1, cutoff=0.5)
            
            # For the first paragraph, we put a placeholder or skip if not 90%
            pass1_paragraph_words.append("_____") 
            
            if match2:
                pass2_paragraph_words.append(match2[0])
            else:
                pass2_paragraph_words.append(f"[{word}]") # Mark words totally missing
                not_caught_list.append(word)

    # --- OUTPUT ---
    
    print("### 1ST OUTPUT: HIGH ACCURACY PARAGRAPH (90% Match Only)")
    print("-" * 50)
    print(" ".join(pass1_paragraph_words))
    print("\n" + "="*60 + "\n")

    print("### 2ND OUTPUT: RECOVERED PARAGRAPH (Including 80%/Fuzzy Matches)")
    print("-" * 50)
    print(" ".join(pass2_paragraph_words))
    
    print("\n" + "="*60 + "\n")
    print("THESE ARE NOT CAUGHT AND NOT IN YOUR DATASET:")
    if not_caught_list:
        print(set(not_caught_list)) # Use set to remove duplicate failures
    else:
        print("None")

# Your Input Data
noisy_test = """ආයිබෝවන් මම රේනුක ට පුළුවනිෝබට සහයවන්න ගේබලත්ම ශකකලබලල කියන්න මැඩ එන්ටකරපු නම් එක අදාලවත කනෙක්ෂණකි 
වස්කර බිඑකයිකයි විසි හතරයි දහ නම යයි අතසිය හ්ත එකනන් එකද මමඩම් කනේෂ එකට අදාව අයිතිකර්ෙ නම තැනකන්න පුළුවන්තනල මතිමෙරදී ඉන්නාමඩීලකෂ ල 
බකියන් කරාක ඇමතිමෙ රදීනමට රනදසර සෞදි් නත්දැනනෙක්ෂඑක වෙල්ප නිසා දක්කැන්ලතිය දැනතව ොවෙඹ කාලසනොවෙම්බ තිහ දක්වා රුපියල් දහුන් සාරසය  දෙක්තහැ 
දකකමදත්තයවා බල්පතීමිලරහසෙනරන්නේ දිසෙම්බ ිසිදෙක තමයි ජඩේක ටිලෙන නොවෙන්බ බහට පීමට් ික කර කනෙක්න් ටික ඔතෝ් තික ටික වෙලාවකින් ත්ූවෙනවා රදපමඩම් ේමන් ෙක්
කරලා තියෙන්නේ ඕදිසේබ විසහ අට දිට පත්සයීමන් එිකක්ද තමනං අභ්ෙිලානපේකරපු මෞ්ික කියදකර දැනන්න පුළුවන්ද මට ට ඩීටල්ස් ික දෙන්නුල අනුලින්ද කෝම්ද පීම්ක කරබැකකවුට්
එකෙන් මැඩ්ගේ මවුන් එකදඩ්ත ලනන්තාංශික්ෂණ ෙෆරනස් නම් එකත් මැඩම ලබාකත්ත ගේන කම්න කත් දානම ට කරපු වෙලාව කියන්න තයි හතිස් පහයුත්කරපු බැං එක මොකක්දමට 
නේමේෂන් ත්පැ්එකනහතහතලිස්පහනත වෙලාව මඩ  සංශක්ෂ් රෆ් නම් එක දේන පුළන්ද මට ලෝ මැනතලන්න කෙරෙන්න හනේ ෝඅභ්ට්ටලා නැහැමන මෙතකොට පි කර්නේ බිල්ම්තන ක් දාල
කැන්ණ කත්තිය් ක ක බිලින් ප්ින් තමසැලට අ්තනෙත් රමට්ටිය කරන් නං කම්තර එකාන ටික වෙලාවකින් මකික්වයිමටසාංශික්ෂ නම් එකතෙන්න පුළුවන්ද ්්අතසීය හත්තතුනයිදෙසියානු පහතාකන
යිතිකරුම ට කතා කරන්නේ මට කනට්මබල් නම් එක මඩ ම කල්කරන නම් කට ම ිල්කම් තැ එකක් ුොර මම යො ොකරපු කක්යන කට දාළ පකරන නම් එක මැඩට කල්කරන මබලි් න් එකට එ 
සලත් එකක් පන්රකනෙක්ෂ කත් ැත්තයු ක තක්ම ටික වෙලාකන් කකළ බලන්න රි එල්තී මොබිටර මොට සමෙම හරිමඩ වෙනත්ම දැනිරීමට අවශ්‍යද මාලබා දුන් සේවය ඇගම දහ දයු තන්න සතති 
මොභිටලමොට ස්තුතිය සපත"""

check_noisy_sentence(noisy_test)
# Out:
# ### 1ST OUTPUT: HIGH ACCURACY PARAGRAPH (90% Match Only)
# --------------------------------------------------
# ...

# %%
import difflib

def check_noisy_sentence(noisy_input):
    # 1. Load your dataset
    try:
        with open(r"D:\SLT\Test 3\my_dataset.txt", 'r', encoding='utf-8') as f:
            dataset = [line.strip().replace(',', '') for line in f if line.strip()]
    except FileNotFoundError:
        print("Error: Dataset file not found.")
        return

    noisy_words = noisy_input.split()
    
    # Lists to store the final words for paragraph reconstruction
    pass1_paragraph_words = []
    pass2_paragraph_words = []
    not_caught_list = []

    for word in noisy_words:
        # Pass 1: High Accuracy (90% match)
        match1 = difflib.get_close_matches(word, dataset, n=1, cutoff=0.9)
        
        if match1:
            pass1_paragraph_words.append(match1[0])
            pass2_paragraph_words.append(match1[0]) # If it's perfect, it goes in both
        else:
            # Word failed Pass 1, let's try Pass 2: Fuzzy Recovery (50% match)
            match2 = difflib.get_close_matches(word, dataset, n=1, cutoff=0.5)
            
            # For the first paragraph, we put a placeholder or skip if not 90%
            pass1_paragraph_words.append("_____") 
            
            if match2:
                pass2_paragraph_words.append(match2[0])
            else:
                pass2_paragraph_words.append(f"[{word}]") # Mark words totally missing
                not_caught_list.append(word)

    # --- OUTPUT ---
    
    print("### 1ST OUTPUT: HIGH ACCURACY PARAGRAPH (90% Match Only)")
    print("-" * 50)
    print(" ".join(pass1_paragraph_words))
    print("\n" + "="*60 + "\n")

    print("### 2ND OUTPUT: RECOVERED PARAGRAPH (Including 80%/Fuzzy Matches)")
    print("-" * 50)
    print(" ".join(pass2_paragraph_words))
    
    print("\n" + "="*60 + "\n")
    print("THESE ARE NOT CAUGHT AND NOT IN YOUR DATASET:")
    if not_caught_list:
        print(set(not_caught_list)) # Use set to remove duplicate failures
    else:
        print("None")

# Your Input Data
noisy_test = """එබවන් මම රක්ෂිමට පුුව්න බිඩ සහයවන්නලෝසගේියන්න්ලෑස්ටු නදිකය්කිපැකජ් එකකයිදව ට දනග ලුතන් දනනේේන්නමිටෝම් ප්ලස්සියලවසදග ගෙන කොඩක්
වසර ෙනපුළ්අනමිටඩ් හෝම් ්ලස් පැකේජ්කේ රේැඳනසාරඳසනට ස්තූතියි අිිටඩ් හෝම් ප්ලස්පැකේජේ රෙන්ටලික ිපල් නවදාස් නවසේයයි සර ඒකස්පී්එක ටුහන් රෙන්බිපිය්ටිනවා දවනලෝඩ්ස්පීඩ් එක 
ව්හන්රන්බියස් ටියනවා අප්ලෝඩ්්ීඩ් එක රිස්ත්‍රික්ෂණඑකක් නැහැ අනුලමිට ඩියුස් කරන්න පුළුව් පොයිස් කෝල්සු ත්ලිමිටත් ගන්න ුළුවන්සාතකොටන්නමිට් හෝ් කිය එයිමේ ලස්සගෙි ෙනස්ක ්පීඩ් 
එක මගේ දැන් ්්ක්ටු ෙන්ි පයිගෙන අලුත පැකේකින් ැද්ෆ්ලෑස්න්ටිෆර්කත්තයන ආාන දන් ම අන්ිමට හම ්ල්සගෙන මාරුන්  ආයවනම් ෆ්ලෑ්ු වෙඩ පරගන මාරෙන් පුුවන් පුළුවන්සම කොහොමද 
න්ලිට් හම ප්ලස්සකෙනමාවෙන්මෙතනින්සට මාරු කරල දන්න පුළුවන් කනක්ෂණ් එක යිටිකරගේ අඩී න්ෙක්කියන්න ුුවන්ද සටයයිහැටහ්තයහේටඋනිහනේ  අසු නහසකරනක ඇමතමේ ර්දෙන්නමතිම
රඳින් සිටට ස්තූතය සහද දවසත්ුද පකජ්එකබ්ඩේට් වනවන්සට තකල් ගේ ද්ටමේ තියන පැකේකේ හුස් කරන්න පුළුවන් කොහොමත් මෙපකේ්කට දින ෙක්කට දාලවලන්තක ඇඩ්ද ාමේ මාසේ බිල් එකට
හෙුවෙ මෙමනසේ සම අද දවසදී මේ පැකජකේ් රන්න දවඇතලත ලුත් පැකේජ් ක අප්ඩට ෙන සාගැන මට ය පස්සේ ඕනොත් මද අඩු ැින් එකරු් මාරුවෙන්න පුළුවන් පුළුවන්සගැටක් නැහැ ගනට 
කාලයක් තයනා කජ්යක් දාල ්පට ා් ඉන්නඕනනිවාරයන්එහෙම එකක්න ැබැයි මේඩෞන්ග්‍රේඩ් එකක් ක්‍රික්වස් කරනවානංසව දෞ්්‍කැනිදන්ම යාලිමිට ෆයබ ්ලෑන්ලතයක් ිහෙමමකුත් වරට්රස් එකක් නැහැ
ඒත් නොමකෙනඩෞන්ග්‍රේඩ් එකක් යනවනම් බිලින් ිකටතමයි න්ග‍රේට් කරගන් ළගෙන්ගෙන න මසකාලවෙනිඩ විතරයසලෙසතමබි්තුතේ සැප දවසක්ස"""

check_noisy_sentence(noisy_test)
# Out:
# ### 1ST OUTPUT: HIGH ACCURACY PARAGRAPH (90% Match Only)
# --------------------------------------------------
# ...

# %%
import difflib

def check_noisy_sentence(noisy_input):
    # 1. Load your dataset
    try:
        with open(r"D:\SLT\Test 3\my_dataset.txt", 'r', encoding='utf-8') as f:
            dataset = [line.strip().replace(',', '') for line in f if line.strip()]
    except FileNotFoundError:
        print("Error: Dataset file not found.")
        return

    noisy_words = noisy_input.split()
    
    # Lists to store the final words for paragraph reconstruction
    pass1_paragraph_words = []
    pass2_paragraph_words = []
    not_caught_list = []

    for word in noisy_words:
        # Pass 1: High Accuracy (90% match)
        match1 = difflib.get_close_matches(word, dataset, n=1, cutoff=0.9)
        
        if match1:
            pass1_paragraph_words.append(match1[0])
            pass2_paragraph_words.append(match1[0]) # If it's perfect, it goes in both
        else:
            # Word failed Pass 1, let's try Pass 2: Fuzzy Recovery (50% match)
            match2 = difflib.get_close_matches(word, dataset, n=1, cutoff=0.5)
            
            # For the first paragraph, we put a placeholder or skip if not 90%
            pass1_paragraph_words.append("_____") 
            
            if match2:
                pass2_paragraph_words.append(match2[0])
            else:
                pass2_paragraph_words.append(f"[{word}]") # Mark words totally missing
                not_caught_list.append(word)

    # --- OUTPUT ---
    
    print("### 1ST OUTPUT: HIGH ACCURACY PARAGRAPH (90% Match Only)")
    print("-" * 50)
    print(" ".join(pass1_paragraph_words))
    print("\n" + "="*60 + "\n")

    print("### 2ND OUTPUT: RECOVERED PARAGRAPH (Including 80%/Fuzzy Matches)")
    print("-" * 50)
    print(" ".join(pass2_paragraph_words))
    
    print("\n" + "="*60 + "\n")
    print("THESE ARE NOT CAUGHT AND NOT IN YOUR DATASET:")
    if not_caught_list:
        print(set(not_caught_list)) # Use set to remove duplicate failures
    else:
        print("None")

# Your Input Data
noisy_test = """යිබෝවන් මරානිමඩපොලනිපුට සහය වන්නයඩුව ේමිස් අපේ පියෝටීවි එකයි තෙලිපුරනයින් එකයි දෙකම වැඩ නැහැටමීට දවස් දපලින් විල්ලත් හැුවා හැදුවත
ඒ විදිහටම ආය මේ නැව  ක්තිය වෙලා තිෙනවාතෙලිෝන් එයි පියෝටීවි එකයිකනක්ෂණ එකිටකරුගෙනමෙන්ඩබ්ලි පීපී ඒ කුමාරපයිබලයින් එකක්යලින්ත්‍රයඩ් එක වැඩකරනදනෑමොකම ැඩනෑඑල්ලවසි ග
ෙන ලයි් කරෙඩ්වලා තින්ද බලනවෙන් වෙලා ියරෙඩ්වෙලා තයෙනවම්පෙන් එක ඇතුළත් කරන්නෑ මට සම්බලගරන් මභය නම්ම ් බින්ද හතයි හයයිරිඅසුතුනයි හඅනු එ්කයි රිටසිය පනස්පහැතිමි බ
ැිනොනව ඳිනස නගත ස්තුතියි ම අදාලඩපන්හදනටීමකට එක ව ක්පෙන් එක දන්නෙල ලාවක්පනබය නම්බකටසෙර්ත් එකක් ගවල් මසරීමඩල ති්තූය සබ දවසසක් මෙව මැගම සඳා රැඳී සිටින්න"""

check_noisy_sentence(noisy_test)
# Out:
# ### 1ST OUTPUT: HIGH ACCURACY PARAGRAPH (90% Match Only)
# --------------------------------------------------
# _____ _____ සහය _____ _____ අපේ _____ _____ _____ _____ _____ වැඩ _____ දවස් _____ _____ _____ _____ _____ විදිහටම _____ මේ _____ _____ වෙලා _____ _____ _____ _____ _____ _____ _____ _____ _____ එක _____ _____ _____ _____ _____ _____ _____ _____ වෙලා _____ _____ එක ඇතුළත් _____ මට _____ _____ _____ _____ _____ හතයි _____ _____ _____ _____ _____ _____ _____ _____ _____ _____ _____ _____ එක _____ _____ එක _____ _____ _____ එකක් _____ _____ _____ _____ දවසක් _____ _____ _____ රැඳී සිටින්න
#
# ...
#
# ### 2ND OUTPUT: RECOVERED PARAGRAPH (Including 80%/Fuzzy Matches)
# --------------------------------------------------
# ...
